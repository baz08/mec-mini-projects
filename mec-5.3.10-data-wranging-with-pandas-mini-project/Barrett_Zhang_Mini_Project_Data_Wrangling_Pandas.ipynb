# %% [markdown]
# # Mini-Project: Data Wrangling and Transformation with Pandas
#
# Working with tabular data is a necessity for anyone with enterprises having a majority of their data in relational databases and flat files. This mini-project is adopted from the excellent tutorial on pandas by Brandon Rhodes which you have watched earlier in the Data Wrangling Unit. In this mini-project, we will be looking at some interesting data based on movie data from the IMDB.
#
# This assignment should help you reinforce the concepts you learnt in the curriculum for Data Wrangling and sharpen your skills in using Pandas. Good Luck!

# %% [markdown]
# ### Please make sure you have one of the more recent versions of Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# ## Taking a look at the Movies dataset
# This data shows the movies based on their title and the year of release

# %%
movies = pd.read_csv('titles.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244914 entries, 0 to 244913
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   244914 non-null  object
#  1   year    244914 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.7+ MB

# %%
movies.head()
# Out:
#                                           title  year
# 0                        The Ticket to the Life  2009
# 1  Parallel Worlds: A New Rock Music Experience  2016
# 2                     Morita - La hija de Jesus  2008
# 3                                           Gun  2017
# 4                        Love or Nothing at All  2014

# %% [markdown]
# ## Taking a look at the Cast dataset
#
# This data shows the cast (actors, actresses, supporting roles) for each movie
#
# - The attribute `n` basically tells the importance of the cast role, lower the number, more important the role.
# - Supporting cast usually don't have any value for `n`

# %%
cast = pd.read_csv('cast.csv.zip')
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786176 entries, 0 to 3786175
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   title      object
#  1   year       int64
#  2   name       object
#  3   type       object
#  4   character  object
#  5   n          float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 173.3+ MB

# %%
cast.head(10)
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# ...

# %% [markdown]
# ## Taking a look at the Release dataset
#
# This data shows details of when each movie was release in each country with the release date

# %%
release_dates = pd.read_csv('release_dates.csv', parse_dates=['date'], infer_datetime_format=True)
release_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479488 entries, 0 to 479487
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   title    479488 non-null  object
#  1   year     479488 non-null  int64
#  2   country  479488 non-null  object
#  3   date     479488 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 14.6+ MB

# %%
release_dates.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %% [markdown]
# # Section I - Basic Querying, Filtering and Transformations

# %% [markdown]
# ### What is the total number of movies?

# %%
len(movies)
# Out:
# 244914

# %% [markdown]
# ### List all Batman movies ever made

# %%
batman_df = movies[movies.title == 'Batman']
print('Total Batman Movies:', len(batman_df))
batman_df
# Out:
# Total Batman Movies: 2
#          title  year
# 52734   Batman  1943
# 150621  Batman  1989

# %% [markdown]
# ### List all Batman movies ever made - the right approach

# %%
batman_df = movies[movies.title.str.contains('Batman', case=False)]
print('Total Batman Movies:', len(batman_df))
batman_df.head(10)
# Out:
# Total Batman Movies: 35
#                                              title  year
# 16813                              Batman: Anarchy  2016
# 30236                               Batman Forever  1995
# 31674                                Batman Untold  2010
# 31711  Scooby-Doo & Batman: the Brave and the Bold  2018
# 41881                  Batman the Rise of Red Hood  2018
# 43484        Batman: Return of the Caped Crusaders  2016
# 46333                               Batman & Robin  1997
# 51811                              Batman Revealed  2012
# 52734                                       Batman  1943
# 56029                 Batman Beyond: Rising Knight  2014

# %% [markdown]
# ### Display the top 15 Batman movies in the order they were released

# %%
batman_df.sort_values(by=['year'], ascending=True).iloc[:15]
# Out:
#                                title  year
# 52734                         Batman  1943
# 100056              Batman and Robin  1949
# 161439                Batman Dracula  1964
# 84327          Alyas Batman at Robin  1965
# 68364                   James Batman  1966
# 161527             Batman: The Movie  1966
# 56159          Batman Fights Dracula  1967
# 168504         Fight! Batman, Fight!  1973
# 150621                        Batman  1989
# 156239         Alyas Batman en Robin  1991
# 156755                Batman Returns  1992
# 63366   Batman: Mask of the Phantasm  1993
# 30236                 Batman Forever  1995
# 46333                 Batman & Robin  1997
# 208220                 Batman Begins  2005

# %% [markdown]
# ### Section I - Q1 : List all the 'Harry Potter' movies from the most recent to the earliest

# %%
harry_df = movies[movies.title.str.contains('Harry Potter', case = False)]
harry_df.sort_values(by=['year'], ascending = False)
# Out:
#                                                title  year
# 143147  Harry Potter and the Deathly Hallows: Part 2  2011
# 152831  Harry Potter and the Deathly Hallows: Part 1  2010
# 109213        Harry Potter and the Half-Blood Prince  2009
# 50581      Harry Potter and the Order of the Phoenix  2007
# 187926           Harry Potter and the Goblet of Fire  2005
# 61957       Harry Potter and the Prisoner of Azkaban  2004
# 82791        Harry Potter and the Chamber of Secrets  2002
# 223087         Harry Potter and the Sorcerer's Stone  2001

# %% [markdown]
# ### How many movies were made in the year 2017?

# %%
len(movies[movies.year == 2017])
# Out:
# 11474

# %% [markdown]
# ### Section I - Q2 : How many movies were made in the year 2015?

# %%
len(movies[movies.year == 2015])
# Out:
# 8702

# %% [markdown]
# ### Section I - Q3 : How many movies were made from 2000 till 2018?
# - You can chain multiple conditions using OR (`|`) as well as AND (`&`) depending on the condition

# %%
len(movies[movies.year.isin(range(2000, 2018))])
# Out:
# 106029

# %% [markdown]
# ### Section I - Q4: How many movies are titled "Hamlet"?

# %%
ham_df  = movies[movies.title.str.contains('Hamlet', case = False)]
ham_df
# Out:
#                                           title  year
# 1931                                     Hamlet  2009
# 8214                                     Hamlet  1976
# 10364                             Hamlet A.D.D.  2014
# 17531                            Hamlet's Ghost  2015
# 17833                             Zombie Hamlet  2012
# 40045                               Hamlet (II)  2005
# 44571                               Hamlet (II)  2015
# 46344                                    Hamlet  1921
# 47248                    Hamlet liikemaailmassa  1987
# 50271                            Hamlet/Horatio  2017
# 51236                            Hamlet Unbound  2012
# 52408                 Hamlet the Vampire Slayer  2008
# 55525                    Hamlet in the Hamptons  2002
# 55639                                    Hamlet  2000
# 55951                               Fuck Hamlet  1996
# 66134                        Han, hun og Hamlet  1922
# ...

# %% [markdown]
# ### Section I - Q5: List all movies titled "Hamlet"
# - The movies should only have been released on or after the year 2000
# - Display the movies based on the year they were released (earliest to most recent)

# %%
ham_rec =ham_df.sort_values(by = ['year'], ascending = True)
ham_rec[ham_rec.year >=2000]
# Out:
#                                           title  year
# 55639                                    Hamlet  2000
# 55525                    Hamlet in the Hamptons  2002
# 137905                                 Hamlet_X  2003
# 218468                                 Hamlet X  2004
# 152920          Dogg's Hamlet, Cahoot's Macbeth  2005
# 40045                               Hamlet (II)  2005
# 200246  The Tragedy of Hamlet Prince of Denmark  2007
# 156899                             Hamlet (III)  2007
# 176528                              Hamlet (II)  2007
# 141237                                 Hamlet 2  2008
# 52408                 Hamlet the Vampire Slayer  2008
# 191734                           Kitchen Hamlet  2009
# 1931                                     Hamlet  2009
# 220674                     Hamlet Demonstration  2011
# 227953                                   Hamlet  2011
# 51236                            Hamlet Unbound  2012
# ...

# %% [markdown]
# ### Section I - Q6: How many roles in the movie "Inception" are of the supporting cast (extra credits)
# - supporting cast are NOT ranked by an "n" value (NaN)
# - check for how to filter based on nulls

# %%
inception_df = cast[cast.title == 'Inception']
supporting_df = inception_df[inception_df.n.isna()]
supporting_df
# Out:
#              title  year                     name     type  \
# 98153    Inception  2010     Michael (III) August    actor
# 197877   Inception  2010                 Ken Bhan    actor
# 374661   Inception  2010            John Ceallach    actor
# 497161   Inception  2010             Garvin Cross    actor
# 684098   Inception  2010            Seve Esposito    actor
# 690634   Inception  2010      Marcus (II) Everett    actor
# 707642   Inception  2010  Zachary Christopher Fay    actor
# 836295   Inception  2010        Daniel Girondeaud    actor
# 1006636  Inception  2010          Andrew Hoagland    actor
# 1095095  Inception  2010          Charles Jarrell    actor
# 1108755  Inception  2010            Seong-hwan Jo    actor
# 1120184  Inception  2010          Alonzo F. Jones    actor
# 1189066  Inception  2010               Mobin Khan    actor
# 1248176  Inception  2010            Shunsaku Kud?    actor
# 1296268  Inception  2010         John (IX) Lawson    actor
# ...

# %% [markdown]
# ### Section I - Q7: How many roles in the movie "Inception" are of the main cast
# - main cast always have an 'n' value

# %%
main_df = inception_df[inception_df.n.notna()]
main_df
# Out:
#              title  year                  name     type  \
# 149008   Inception  2010          Peter Basham    actor
# 183937   Inception  2010          Tom Berenger    actor
# 260128   Inception  2010        Virgile Bramly    actor
# 326745   Inception  2010         Michael Caine    actor
# 333415   Inception  2010          Earl Cameron    actor
# 433867   Inception  2010         Nicolas Clerc    actor
# 444385   Inception  2010        Adam (IV) Cole    actor
# 517227   Inception  2010    Jean-Michel Dagory    actor
# 590576   Inception  2010     Leonardo DiCaprio    actor
# 709436   Inception  2010             Russ Fega    actor
# 737322   Inception  2010      Mark Fleischmann    actor
# 807795   Inception  2010        Michael Gaston    actor
# 812135   Inception  2010       Johnathan Geare    actor
# 832083   Inception  2010         Carl Gilliard    actor
# 833376   Inception  2010           Jack Gilroy    actor
# 859993   Inception  2010  Joseph Gordon-Levitt    actor
# ...

# %% [markdown]
# ### Section I - Q8: Show the top ten cast (actors\actresses) in the movie "Inception"
# - main cast always have an 'n' value
# - remember to sort!

# %%
top_main = main_df.sort_values(by = 'n', ascending = True)
top_main.head(10)
# Out:
#              title  year                  name     type        character     n
# 590576   Inception  2010     Leonardo DiCaprio    actor             Cobb   1.0
# 859993   Inception  2010  Joseph Gordon-Levitt    actor           Arthur   2.0
# 3387147  Inception  2010            Ellen Page  actress          Ariadne   3.0
# 940923   Inception  2010             Tom Hardy    actor            Eames   4.0
# 2406531  Inception  2010          Ken Watanabe    actor            Saito   5.0
# 1876301  Inception  2010            Dileep Rao    actor            Yusuf   6.0
# 1615709  Inception  2010        Cillian Murphy    actor   Robert Fischer   7.0
# 183937   Inception  2010          Tom Berenger    actor         Browning   8.0
# 2765969  Inception  2010      Marion Cotillard  actress              Mal   9.0
# 1826027  Inception  2010    Pete Postlethwaite    actor  Maurice Fischer  10.0

# %% [markdown]
# ### Section I - Q9:
#
# (A) List all movies where there was a character 'Albus Dumbledore'
#
# (B) Now modify the above to show only the actors who played the character 'Albus Dumbledore'
# - For Part (B) remember the same actor might play the same role in multiple movies

# %%
albus_df = cast[cast.character == 'Albus Dumbledore']
alb_movies = albus_df['title']
alb_movies
# Out:
# 704984                                    Epic Movie
# 792421           Harry Potter and the Goblet of Fire
# 792423     Harry Potter and the Order of the Phoenix
# 792424      Harry Potter and the Prisoner of Azkaban
# 947789       Harry Potter and the Chamber of Secrets
# 947790         Harry Potter and the Sorcerer's Stone
# 1685537                        Ultimate Hero Project
# 2248085                                       Potter
# Name: title, dtype: object

# %%
albus_df['name'].drop_duplicates()
# Out:
# 704984            Dane Farwell
# 792421          Michael Gambon
# 947789          Richard Harris
# 1685537    George (X) O'Connor
# 2248085      Timothy Tedmanson
# Name: name, dtype: object

# %% [markdown]
# ### Section I - Q10:
#
# (A) How many roles has 'Keanu Reeves' played throughout his career?
#
# (B) List the leading roles that 'Keanu Reeves' played on or after 1999 in order by year.

# %%
keanu_df = cast[cast.name.str.contains('Keanu Reeves', case =False)]
print('Keanu has played ' + str(len(keanu_df)) + ' roles')
# Out:
# Keanu has played 62 roles

# %%
keanu_roles = keanu_df[(keanu_df.year >=1999) & (keanu_df.n == 1.0)].dropna()
keanu_roles = keanu_roles.sort_values(by = 'year', ascending = True)
keanu_roles
# Out:
#                                  title  year          name   type  \
# 1892390                     The Matrix  1999  Keanu Reeves  actor
# 1892397               The Replacements  2000  Keanu Reeves  actor
# 1892358                      Hard Ball  2001  Keanu Reeves  actor
# 1892383                 Sweet November  2001  Keanu Reeves  actor
# 1892348                    Constantine  2005  Keanu Reeves  actor
# 1892388                 The Lake House  2006  Keanu Reeves  actor
# 1892382                   Street Kings  2008  Keanu Reeves  actor
# 1892385  The Day the Earth Stood Still  2008  Keanu Reeves  actor
# 1892359                  Henry's Crime  2010  Keanu Reeves  actor
# 1892342                       47 Ronin  2013  Keanu Reeves  actor
# 1892361                      John Wick  2014  Keanu Reeves  actor
# 1892366                    Knock Knock  2015  Keanu Reeves  actor
# 1892399                The Whole Truth  2016  Keanu Reeves  actor
# ...

# %% [markdown]
# ### Section I - Q11:
#
# (A) List the total number of actor and actress roles available from 1950 - 1960
#
# (B) List the total number of actor and actress roles available from 2007 - 2017

# %%
fifty_roles = cast[cast.year.between(1950, 1960, inclusive = True)]
#fifty_roles = cast[(1950 <= cast.year) & (cast.year<= 1960)]
len(fifty_roles)
# Out:
# C:\ProgramData\Anaconda3\envs\mec-miniprojects\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   """Entry point for launching an IPython kernel.
# 234635

# %%
two_roles = cast[cast.year.between(2007, 2017, inclusive =True)]
#two_roles = cast[(2007 <= cast.year) & (cast.year<= 2017)]
len(two_roles)
# Out:
# C:\ProgramData\Anaconda3\envs\mec-miniprojects\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   """Entry point for launching an IPython kernel.
# 1452413

# %% [markdown]
# ### Section I - Q12:
#
# (A) List the total number of leading roles available from 2000 to present
#
# (B) List the total number of non-leading roles available from 2000 - present (exclude support cast)
#
# (C) List the total number of support\extra-credit roles available from 2000 - present

# %%
lead_roles =  cast[(cast.n == 1) & (2000<=cast.year)]
len(lead_roles)
# Out:
# 60568

# %%
main_roles = cast[(cast.n.notna()) & (cast.n > 1.0)]
len(main_roles)
# Out:
# 2174370

# %%
supp_roles = cast[cast.n.isna()]
len(supp_roles)
# Out:
# 1458573

# %% [markdown]
# # Section II - Aggregations, Transformations and Visualizations

# %% [markdown]
# ## What are the top ten most common movie names of all time?

# %%
top_ten = movies.title.value_counts()[:10]
top_ten
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# Maya                    12
# Temptation              12
# The Outsider            12
# Freedom                 11
# The Three Musketeers    11
# Honeymoon               11
# Othello                 11
# Name: title, dtype: int64

# %% [markdown]
# ### Plot the top ten common movie names of all time

# %%
top_ten.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section II - Q1:  Which years in the 2000s saw the most movies released? (Show top 3)

# %%
two_ts = movies[movies.year.between(2000,2010)]
top_year = two_ts.year.value_counts()[:3]
top_year
# Out:
# 2010    6415
# 2009    6125
# 2008    5151
# Name: year, dtype: int64

# %% [markdown]
# ### Section II - Q2: # Plot the total number of films released per-decade (1890, 1900, 1910,....)
# - Hint: Dividing the year and multiplying with a number might give you the decade the year falls into!
# - You might need to sort before plotting

# %%
def get_decade(y):
    cent = int(y / 100) * 100
    year = y - cent
    dec = year /10 *10 -(year%10)
    return int(cent + dec)
movies['decade'] = movies['year'].map(get_decade)
movies.sort_values(by = 'decade', ascending = True)
def count_rows(rows):
    return len(rows) 
by_decade = movies.groupby('decade').apply(count_rows)
by_decade
plt.plot(by_decade)
plt.xlabel('decade')
plt.ylabel('movies released')
plt.title('Movies Released per Decade')
# Out:
# Text(0.5, 1.0, 'Movies Released per Decade')

# %% [markdown]
# ### Section II - Q3:
#
# (A) What are the top 10 most common character names in movie history?
#
# (B) Who are the top 10 people most often credited as "Herself" in movie history?
#
# (C) Who are the top 10 people most often credited as "Himself" in movie history?

# %%
top_names = cast.character.value_counts()[:10]
top_names
# Out:
# Himself        20746
# Dancer         12477
# Extra          11948
# Reporter        8434
# Student         7773
# Doctor          7669
# Party Guest     7245
# Policeman       7029
# Nurse           6999
# Bartender       6802
# Name: character, dtype: int64

# %%
herself = cast[cast.character == 'Herself']
top_her = herself.name.value_counts()[:10]
top_her
# Out:
# Queen Elizabeth II           12
# Joyce Brothers                9
# Luisa Horga                   9
# Mar?a Luisa (V) Mart?n        9
# Margaret Thatcher             8
# Hillary Clinton               8
# In?s J. Southern              6
# Mar?a Isabel (III) Mart?n     6
# Marta Berrocal                6
# Sumie Sakai                   6
# Name: name, dtype: int64

# %%
himself = cast[cast.character == 'Himself']
top_him = himself.name.value_counts()[:10]
top_him
# Out:
# Adolf Hitler             99
# Richard Nixon            44
# Ronald Reagan            41
# John F. Kennedy          37
# George W. Bush           25
# Winston Churchill        24
# Martin Luther King       23
# Ron Jeremy               22
# Bill Clinton             22
# Franklin D. Roosevelt    21
# Name: name, dtype: int64

# %% [markdown]
# ### Section II - Q4:
#
# (A) What are the top 10 most frequent roles that start with the word "Zombie"?
#
# (B) What are the top 10 most frequent roles that start with the word "Police"?
#
# - Hint: The `startswith()` function might be useful

# %%
zombie = cast[cast.character.str.startswith('Zombie')]
zombie_roles = zombie.character.value_counts()[:10]
zombie_roles
# Out:
# Zombie                         6264
# Zombie Horde                    206
# Zombie - Protestor - Victim      78
# Zombie Extra                     70
# Zombie Dancer                    43
# Zombie Girl                      36
# Zombie #1                        36
# Zombie #2                        31
# Zombie Vampire                   25
# Zombie Victim                    22
# Name: character, dtype: int64

# %%
po = cast[cast.character.str.startswith('Police')]
po_roles = po.character.value_counts()[:10]
po_roles
# Out:
# Policeman              7029
# Police Officer         4808
# Police Inspector        742
# Police Sergeant         674
# Police officer          539
# Police                  456
# Policewoman             415
# Police Chief            410
# Police Captain          387
# Police Commissioner     337
# Name: character, dtype: int64

# %% [markdown]
# ### Section II - Q5: Plot how many roles 'Keanu Reeves' has played in each year of his career.

# %%
by_year = keanu_df.groupby('year').apply(count_rows)
plt.plot(by_year)

# %% [markdown]
# ### Section II - Q6: Plot the cast positions (n-values) of Keanu Reeve's roles through his career over the years.

# %%
plt.scatter(keanu_df.year, keanu_df.n)

# %% [markdown]
# ### Section II - Q7: Plot the number of "Hamlet" films made by each decade

# %%
ham_df['decade'] = ham_df['year'].map(get_decade)
ham_decade = ham_df.groupby('decade').apply(count_rows)
plt.plot(ham_decade)
# Out:
# C:\ProgramData\Anaconda3\envs\mec-miniprojects\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Section II - Q8:
#
# (A) How many leading roles were available to both actors and actresses, in the 1960s (1960-1969)?
#
# (B) How many leading roles were available to both actors and actresses, in the 2000s (2000-2009)?
#
# - Hint: A specific value of n might indicate a leading role

# %%
cast['decade'] = cast['year'].map(get_decade)
sixty_lead = cast[(cast.decade == 1960) & (cast.n == 1)]
len(sixty_lead)
# Out:
# 11823

# %%
thous_lead = cast[(cast.decade == 2000) & (cast.n == 1)]
len(thous_lead)
# Out:
# 26344

# %% [markdown]
# ### Section II - Q9: List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
oz_df = cast[cast.name.str.contains('Frank Oz')]
foz_dup = oz_df[oz_df.title.duplicated(keep = False)]
foz_mult = foz_dup.drop_duplicates(subset = ['title'], keep = 'first')
foz_mult.sort_values(by = 'year', ascending = True)
# Out:
#                                         title  year      name   type  \
# 1723645                      The Muppet Movie  1979  Frank Oz  actor
# 1723598        An American Werewolf in London  1981  Frank Oz  actor
# 1723632                The Great Muppet Caper  1981  Frank Oz  actor
# 1723629                      The Dark Crystal  1982  Frank Oz  actor
# 1723653            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1723601                      Follow That Bird  1985  Frank Oz  actor
# 1723638            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1723608                Muppet Treasure Island  1996  Frank Oz  actor
# 1723612                    Muppets from Space  1999  Frank Oz  actor
# 1723625  The Adventures of Elmo in Grouchland  1999  Frank Oz  actor
#
#                                        character     n  decade
# 1723645                               Miss Piggy   2.0    1970
# 1723598                              Mr. Collins  13.0    1980
# ...

# %% [markdown]
# ### Section II - Q10: List each of the characters that Frank Oz has portrayed at least twice

# %%
foz_char = oz_df[oz_df.character.duplicated(keep = False)]
foz_char.drop_duplicates(subset = ['character'], keep = 'first')
# Out:
#                                              title  year      name   type  \
# 1723599             An American Werewolf in London  1981  Frank Oz  actor
# 1723601                           Follow That Bird  1985  Frank Oz  actor
# 1723602                           Follow That Bird  1985  Frank Oz  actor
# 1723603                           Follow That Bird  1985  Frank Oz  actor
# 1723609                     Muppet Treasure Island  1996  Frank Oz  actor
# 1723610                     Muppet Treasure Island  1996  Frank Oz  actor
# 1723611                     Muppet Treasure Island  1996  Frank Oz  actor
# 1723618  Star Wars: Episode I - The Phantom Menace  1999  Frank Oz  actor
#
#               character     n  decade
# 1723599      Miss Piggy  13.0    1980
# 1723601  Cookie Monster   3.0    1980
# 1723602            Bert   3.0    1980
# 1723603          Grover   3.0    1980
# 1723609     Fozzie Bear  14.0    1990
# 1723610   Sam the Eagle  14.0    1990
# ...

# %% [markdown]
# # Section III - Advanced Merging, Querying and Visualizations

# %% [markdown]
# ## Make a bar plot with the following conditions
# - Frequency of the number of movies with "Christmas" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
christmas = release_dates[(release_dates.title.str.contains('Christmas')) & (release_dates.country == 'USA')]
christmas.date.dt.month.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section III - Q1: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Summer" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by month

# %%
summer = release_dates[(release_dates.title.str.contains('Summer')) & (release_dates.country == 'USA')]
summer.date.dt.month.value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section III - Q2: Make a bar plot with the following conditions
# - Frequency of the number of movies with "Action" in their title
# - Movies should be such that they are released in the USA.
# - Show the frequency plot by week

# %%
action = release_dates[(release_dates.title.str.contains('Action')) & (release_dates.country == 'USA')]
action.date.dt.isocalendar().week.value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section III - Q3: Show all the movies in which Keanu Reeves has played the lead role along with their   release date in the USA sorted by the date of release
# - Hint: You might need to join or merge two datasets!

# %%
keanu = pd.merge(keanu_roles, release_dates, how = 'left', on = ['title', 'year'])
keanu = keanu[keanu.country == 'USA']
keanu.sort_values(by = 'date', ascending = True)
# Out:
#                              title  year          name   type  \
# 0                       The Matrix  1999  Keanu Reeves  actor
# 43                The Replacements  2000  Keanu Reeves  actor
# 78                  Sweet November  2001  Keanu Reeves  actor
# 59                       Hard Ball  2001  Keanu Reeves  actor
# 118                    Constantine  2005  Keanu Reeves  actor
# 158                 The Lake House  2006  Keanu Reeves  actor
# 205                   Street Kings  2008  Keanu Reeves  actor
# 283  The Day the Earth Stood Still  2008  Keanu Reeves  actor
# 320                       47 Ronin  2013  Keanu Reeves  actor
# 366                      John Wick  2014  Keanu Reeves  actor
# 430                    Knock Knock  2015  Keanu Reeves  actor
# 483           John Wick: Chapter 2  2017  Keanu Reeves  actor
#
#                 character    n country       date
# 0                     Neo  1.0     USA 1999-03-31
# 43            Shane Falco  1.0     USA 2000-08-11
# ...

# %% [markdown]
# ### Section III - Q4: Make a bar plot showing the months in which movies with Keanu Reeves tend to be released in the USA?

# %%
keanu.date.dt.month.value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Section III - Q5: Make a bar plot showing the years in which movies with Ian McKellen tend to be released in the USA?

# %%
ian_df = cast[cast.name.str.contains('Ian Mckellen', case = False)]
ian_roles = pd.merge(ian_df, release_dates, how = 'left', on =['title', 'year'])
ian_roles = ian_roles[ian_roles.country == 'USA']
ian_roles.date.dt.year.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>
